# %%
import sys

sys.path.append("../src")

from prediction import predict_message
from prediction import inspect_message

# %%
predict_message("Hi, are we meeting tomorrow?")
# Out:
# {'prediction': 'Ham', 'confidence': 0.999}

# %%
predict_message("URGENT! You have won a free lottery prize. Claim now.")
# Out:
# {'prediction': 'Spam', 'confidence': 0.744}

# %%
predict_message("FREE entry into our competition. Text WIN to 80085.")
# Out:
# {'prediction': 'Spam', 'confidence': 0.61}

# %%
predict_message("Hey bro, are we still meeting tomorrow?")
# Out:
# {'prediction': 'Ham', 'confidence': 1.0}

# %%
predict_message("Can you send me the notes for today's class?")
# Out:
# {'prediction': 'Ham', 'confidence': 1.0}

# %%
inspect_message(
    "Congratulations! You have won $1000. Call now!"
)
# Out:
# Original Message:
# Congratulations! You have won $1000. Call now!
#
# Processed Message:
# congratul call
# 'congratul call'
